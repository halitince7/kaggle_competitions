# %%
deneme
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-add9460287ac> in <cell line: 1>()
# ----> 1 deneme
#
# NameError: name 'deneme' is not defined
